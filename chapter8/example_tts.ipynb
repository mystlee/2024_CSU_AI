# %% [markdown]
# <a href="https://colab.research.google.com/github/mystlee/2024_CSU_AI/blob/main/chapter8/example_tts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch transformers datasets soundfile librosa scipy -qq
# !pip install uroman
# !pip install --upgrade uroman

# %%
import torch
from transformers import VitsTokenizer, VitsModel, set_seed
import os
import subprocess
import scipy
from IPython.display import Audio

tokenizer = VitsTokenizer.from_pretrained("facebook/mms-tts-kor")
model = VitsModel.from_pretrained("facebook/mms-tts-kor")
text = "인공지능을 활용한 음성 합성기 입니다."
inputs = tokenizer(text = text, return_tensors = "pt")

set_seed(47)  # make deterministic
with torch.no_grad():
   outputs = model(inputs["input_ids"])

waveform = outputs.waveform[0]

# %%
scipy.io.wavfile.write("sample_output.wav", rate = model.config.sampling_rate, data = waveform.numpy())
Audio(waveform, rate = model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
